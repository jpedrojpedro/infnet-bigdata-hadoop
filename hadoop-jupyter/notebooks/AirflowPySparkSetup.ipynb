# %%
import findspark
findspark.init()
from pyspark import SparkContext, SparkConf, SQLContext
from pyspark.sql import SparkSession

# %%
conf = SparkConf().setAppName("airflow-pyspark-setup")
sc = SparkContext(conf=conf)
spark = SparkSession(sc)
# Out:
# 26/06/03 02:28:17 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/03 02:28:17 WARN yarn.Client: Neither spark.yarn.jars nor spark.yarn.archive is set, falling back to uploading libraries under SPARK_HOME.

# %%
! hadoop fs -put ../datasets/northwind.db
# Out:
# 26/06/03 02:28:26 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
! hadoop fs -ls /user/root
# Out:
# 26/06/03 02:28:27 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Found 2 items
# drwxr-xr-x   - root supergroup          0 2026-06-03 02:28 /user/root/.sparkStaging
# -rw-r--r--   2 root supergroup   24702976 2026-06-03 02:28 /user/root/northwind.db

# %%
! hadoop fs -put ../datasets/sqlite-jdbc-3.53.0.0.jar
# Out:
# 26/06/03 02:28:28 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
! hadoop fs -ls /user/root
# Out:
# 26/06/03 02:28:29 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Found 3 items
# drwxr-xr-x   - root supergroup          0 2026-06-03 02:28 /user/root/.sparkStaging
# -rw-r--r--   2 root supergroup   24702976 2026-06-03 02:28 /user/root/northwind.db
# -rw-r--r--   2 root supergroup   11964230 2026-06-03 02:28 /user/root/sqlite-jdbc-3.53.0.0.jar

# %%
! hadoop fs -put ../datasets/spark_etl_script.py
# Out:
# 26/06/03 02:28:30 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
! hadoop fs -ls /user/root
# Out:
# 26/06/03 02:28:30 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Found 4 items
# drwxr-xr-x   - root supergroup          0 2026-06-03 02:28 /user/root/.sparkStaging
# -rw-r--r--   2 root supergroup   24702976 2026-06-03 02:28 /user/root/northwind.db
# -rw-r--r--   2 root supergroup       1106 2026-06-03 02:28 /user/root/spark_etl_script.py
# -rw-r--r--   2 root supergroup   11964230 2026-06-03 02:28 /user/root/sqlite-jdbc-3.53.0.0.jar

# %%
! hadoop fs -mkdir /user/root/pyspark-jobs
# Out:
# 26/06/03 02:28:31 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
! hadoop fs -mv /user/root/spark_etl_script.py /user/root/pyspark-jobs/spark_etl_script.py
# Out:
# 26/06/03 02:28:32 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
! hadoop fs -ls /user/root/pyspark-jobs
# Out:
# 26/06/03 02:28:33 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Found 1 items
# -rw-r--r--   2 root supergroup       1106 2026-06-03 02:28 /user/root/pyspark-jobs/spark_etl_script.py

# %%
! hadoop fs -ls /user/root/
# Out:
# 26/06/03 02:52:29 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Found 4 items
# drwxr-xr-x   - root supergroup          0 2026-06-03 02:47 /user/root/.sparkStaging
# -rw-r--r--   2 root supergroup   24702976 2026-06-03 02:28 /user/root/northwind.db
# drwxr-xr-x   - root supergroup          0 2026-06-03 02:28 /user/root/pyspark-jobs
# -rw-r--r--   2 root supergroup   11964230 2026-06-03 02:28 /user/root/sqlite-jdbc-3.53.0.0.jar

# %%
! hadoop fs -mkdir /user/root/mount
# Out:
# 26/06/03 02:53:20 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
! hadoop fs -ls /user/root/
# Out:
# 26/06/03 02:53:51 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Found 5 items
# drwxr-xr-x   - root supergroup          0 2026-06-03 02:47 /user/root/.sparkStaging
# drwxr-xr-x   - root supergroup          0 2026-06-03 02:53 /user/root/mount
# -rw-r--r--   2 root supergroup   24702976 2026-06-03 02:28 /user/root/northwind.db
# drwxr-xr-x   - root supergroup          0 2026-06-03 02:28 /user/root/pyspark-jobs
# -rw-r--r--   2 root supergroup   11964230 2026-06-03 02:28 /user/root/sqlite-jdbc-3.53.0.0.jar
