# %% [markdown]
# ## Spark Structured Streaming — Micro-Batch
#
# Spark Structured Streaming utiliza a abordagem de **micro-batch**: ao invés de processar cada registro individualmente (como faria um sistema evento-a-evento), o Spark acumula dados por um intervalo de tempo (o *trigger*) e processa todos os registros acumulados de uma vez como um batch convencional.
#
# **Pontos-chave do micro-batch neste notebook:**
#
# | Conceito | Descrição |
# |----------|-----------|
# | **Trigger** | Define a frequência dos micro-batches (aqui: `3 minutes`). A cada 3 min o Spark verifica novos arquivos no source e dispara o processamento. |
# | **Checkpoint** | Garante *exactly-once* semantics. Persiste o offset (posição) dos dados já processados para que, em caso de falha, o stream retome de onde parou sem reprocessar nem perder dados. |
# | **Source (FileStreamSource)** | O Spark monitora o diretório HDFS `/user/root/onibus/source2/*/*` por novos arquivos JSON. Arquivos novos detectados desde o último offset são incluídos no próximo batch. |
# | **Sink (foreachBatch)** | Permite aplicar lógica arbitrária de DataFrame em cada micro-batch, possibilitando transformações complexas e escrita customizada. |
# | **Output Mode (append)** | Apenas novos registros são emitidos ao sink — adequado para dados imutáveis de GPS onde não há atualizações de registros passados. |
#
# **Trade-offs do micro-batch vs. streaming contínuo:**
# - ✅ Reutiliza o engine batch do Spark (otimizador Catalyst, Tungsten)
# - ✅ Tolerância a falhas com checkpointing
# - ⚠️ Latência mínima = intervalo do trigger (aqui ~3 min)
# - ⚠️ Dados que chegam no mesmo intervalo de trigger são processados juntos (volume variável por batch)

# %%
import time
import requests
import datetime as dt
from multiprocessing import Process

import findspark
findspark.init()
from pathlib import Path
from pyspark import SparkContext, SparkConf, SQLContext
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, FloatType, LongType
from pyspark.sql.functions import col, regexp_replace, length, desc, row_number
from pyspark.sql import SparkSession, Window

# %%
conf = SparkConf().setAppName("spark-streaming-micro-batch")
sc = SparkContext(conf=conf)
spark = SparkSession(sc)

# %%
def shape(df):
    return (df.count(), len(df.columns))

# %%
! hadoop fs -mkdir -p /user/root/onibus/sink2

# %%
! hadoop fs -mkdir -p /user/root/onibus/source2

# %%
! hadoop fs -mkdir -p /user/root/onibus/checkpoint2

# %%
! hadoop fs -ls /user/root/onibus/
# Out:
# Found 6 items
# drwxr-xr-x   - root supergroup          0 2023-08-25 00:06 /user/root/onibus/checkpoint
# drwxr-xr-x   - root supergroup          0 2023-08-25 00:47 /user/root/onibus/checkpoint2
# drwxr-xr-x   - root supergroup          0 2023-08-25 00:27 /user/root/onibus/sink
# drwxr-xr-x   - root supergroup          0 2023-08-25 00:46 /user/root/onibus/sink2
# drwxr-xr-x   - root supergroup          0 2023-08-25 00:23 /user/root/onibus/source
# drwxr-xr-x   - root supergroup          0 2023-08-25 00:47 /user/root/onibus/source2

# %% [markdown]
# ### Ingestão dos dados (Producer)
#
# A função `call_bus_api` atua como **producer**: faz chamadas HTTP à API de GPS dos ônibus do Rio de Janeiro, obtém posições (latitude, longitude) em near-real-time, e grava cada resposta como um arquivo JSON no HDFS (`source2/`).
#
# A função `loop` chama a API repetidamente a cada 60 segundos, simulando a chegada contínua de dados.
# O Spark Streaming detecta esses novos arquivos a cada intervalo de trigger e os inclui no próximo micro-batch.

# %%
BASE_URL = "https://dados.mobilidade.rio/gps/sppo?" \
           "dataInicial={dt_inicial}+{hora_inicial}&dataFinal={dt_final}+{hora_final}"

# %%
def call_bus_api(interval=60):
    offset = dt.timedelta(hours=3)
    dtf = dt.datetime.now() - offset
    dti = dtf - dt.timedelta(seconds=interval)
    dt_inicial = dti.strftime("%Y-%m-%d")
    dt_final = dtf.strftime("%Y-%m-%d")
    hora_inicial = dti.strftime("%H:%M:%S")
    hora_final = dtf.strftime("%H:%M:%S")
    ret = requests.get(
        BASE_URL.format(
            dt_inicial=dt_inicial, dt_final=dt_final, hora_inicial=hora_inicial, hora_final=hora_final
        )
    )
    rdd = spark.sparkContext.parallelize([ret.text])
    df = spark.read.json(rdd)
    df.write.json(f"/user/root/onibus/source2/{dtf.strftime('%Y%m%d_%H%M%S')}")

# %%
window = Window.partitionBy(
    col("ordem")
).orderBy(
    desc("velocidade")
)

# %% [markdown]
# ### foreachBatch — Processamento de cada micro-batch
#
# A função `handle_stream(bdf, ctrl)` é invocada a cada micro-batch pelo Spark. Os parâmetros:
# - `bdf`: DataFrame estático contendo **todos os registros novos** desse micro-batch
# - `ctrl`: batch ID (identificador sequencial do micro-batch)
#
# Dentro dela:
# 1. **Conversão de tipos** — latitude/longitude de string para float (com troca de `,` por `.`)
# 2. **Filtro** — mantém apenas linhas regulares (código de 3 dígitos)
# 3. **Window function** — para cada ônibus (`ordem`), ranqueia por `velocidade` desc e mantém apenas o top-1
# 4. **Escrita no sink** — salva resultado em CSV no HDFS
#
# Isso demonstra que dentro do `foreachBatch` você tem um DataFrame completo e pode usar **toda a API batch do Spark** (joins, aggregations, window functions, etc.).

# %%
def handle_stream(bdf, ctrl):
    offset = dt.timedelta(hours=3)
    dtt = dt.datetime.now() - offset
    # just data conversion
    df = bdf.withColumn(
        "latitude", regexp_replace(col("latitude"), ",", ".").cast(FloatType())
    ).withColumn(
        "longitude", regexp_replace(col("longitude"), ",", ".").cast(FloatType())
    ).withColumn(
        "datahora", col("datahora").cast(LongType())
    ).withColumn(
        "velocidade", col("velocidade").cast(IntegerType())
    ).withColumn(
        "datahoraenvio", col("datahoraenvio").cast(LongType())
    ).withColumn(
        "datahoraservidor", col("datahoraservidor").cast(LongType())
    )
    # start transformation
    # ordem => carroceria (janela)
    # linhas regulares => tamanho três (filtro)
    df.filter(
        length(df.linha) == 3
    ).withColumn(
        "idx", row_number().over(window)
    ).filter(
        col("idx").isin(1)  # top1 velocidade de cada carroceria nessa janela de tempo
    ).select(
        col("ordem"), col("linha"), col("velocidade")
    ).write.csv(f"/user/root/onibus/sink2/{dtt.strftime('%Y%m%d_%H%M%S')}")

# %%
schema = StructType([
    StructField("ordem", StringType(), True),
    StructField("latitude", StringType(), True),
    StructField("longitude", StringType(), True),
    StructField("datahora", StringType(), True),
    StructField("velocidade", StringType(), True),
    StructField("linha", StringType(), True),
    StructField("datahoraenvio", StringType(), True),
    StructField("datahoraservidor", StringType(), True),
])

# %%
def loop(max_iter=6):
    idx = 1
    while True:
        print(f"{idx} - fetching API")
        call_bus_api()
        if idx == max_iter:
            break
        time.sleep(60)
        idx += 1

# %% [markdown]
# ### readStream + writeStream — Configurando o pipeline de micro-batch
#
# - `readStream.schema(schema).json(...)` — cria um DataFrame de streaming que monitora o diretório HDFS por novos arquivos JSON. O **schema** deve ser fornecido explicitamente (streaming não suporta inferência de schema).
#
# - `.trigger(processingTime="3 minutes")` — a cada 3 minutos, o Spark verifica se há novos dados desde o último checkpoint e dispara um micro-batch. Se não houver dados novos, o batch executa mas processa 0 linhas.
#
# - `.option("checkpointLocation", ...)` — local no HDFS onde o Spark persiste metadados do progresso do stream (offsets, commits). Isso garante **tolerância a falhas**: se o processo cair, ao reiniciar ele retoma do último offset commitado, sem perder nem duplicar dados.
#
# - `.outputMode("append")` — cada micro-batch só emite registros novos. Modos alternativos: `complete` (reemite tudo, útil com aggregations) e `update` (emite apenas linhas alteradas).

# %%
sdf = spark.readStream.schema(schema).json("/user/root/onibus/source2/*/*")

# %%
stream_handle = sdf.writeStream                                                  \
                   .outputMode("append")                                         \
                   .foreachBatch(handle_stream)                                  \
                   .trigger(processingTime="3 minutes")                          \
                   .option("checkpointLocation", "/user/root/onibus/checkpoint2") \
                   .start()

# %%
stream_handle.isActive
# Out:
# True

# %%
stream_handle.status
# Out:
# {'message': 'Waiting for next trigger',
#  'isDataAvailable': False,
#  'isTriggerActive': False}

# %% [markdown]
# ### Monitoramento do stream
#
# - `stream_handle.isActive` — verifica se o stream ainda está rodando
# - `stream_handle.status` — mostra o estado atual (aguardando trigger, processando, etc.)
# - `stream_handle.lastProgress` — métricas do último micro-batch: `numInputRows`, `processedRowsPerSecond`, `durationMs` de cada fase
# - `stream_handle.recentProgress` — histórico recente de batches
#
# Observe no `lastProgress` que `durationMs` detalha quanto tempo cada fase leva:
# - `getOffset`: descobrir novos arquivos
# - `getBatch`: leitura dos dados
# - `queryPlanning`: planejamento da query
# - `addBatch`: execução da transformação (foreachBatch)
# - `walCommit`: commit do checkpoint (Write-Ahead Log)
#
# A variação do `numInputRows` entre batches é natural no micro-batch — depende de quantos dados chegaram entre um trigger e outro.

# %% [markdown]
# #### Batch control
#
# - **batchID** `0` => `perdemos - antes da interrupção - 6_090`
# - **batchID** `1` => `7_474`
# - **batchID** `2` => `25_059`
# - **batchID** `3` => `17_384`
# - **batchID** `4` => previsto: `15_482` / real: `15_482`
# - **batchID** `5` => `0`
# - **total** `49_917 / 56_007`

# %%
stream_handle.lastProgress
# Out:
# {'id': 'aaa8d33d-2584-4d1f-a3b7-e3c707e0552c',
#  'runId': '33371245-cde2-4d37-9e90-9f308cd8792e',
#  'name': None,
#  'timestamp': '2023-08-25T01:12:00.001Z',
#  'batchId': 5,
#  'numInputRows': 16072,
#  'inputRowsPerSecond': 89.28888888888889,
#  'processedRowsPerSecond': 7566.854990583804,
#  'durationMs': {'addBatch': 1179,
#   'getBatch': 52,
#   'getOffset': 756,
#   'queryPlanning': 10,
#   'triggerExecution': 2124,
#   'walCommit': 72},
#  'stateOperators': [],
#  'sources': [{'description': 'FileStreamSource[hdfs://node-master:9000/user/root/onibus/source2/*/*]',
#    'startOffset': {'logOffset': 4},
#    'endOffset': {'logOffset': 5},
#    'numInputRows': 16072,
#    'inputRowsPerSecond': 89.28888888888889,
#    'processedRowsPerSecond': 7566.854990583804}],
#  'sink': {'description': 'ForeachBatchSink'}}

# %%
stream_handle.recentProgress
# Out:
# [{'id': 'aaa8d33d-2584-4d1f-a3b7-e3c707e0552c',
#   'runId': '33371245-cde2-4d37-9e90-9f308cd8792e',
#   'name': None,
#   'timestamp': '2023-08-25T00:53:31.092Z',
#   'batchId': 0,
#   'numInputRows': 5846,
#   'processedRowsPerSecond': 2391.002044989775,
#   'durationMs': {'addBatch': 2111,
#    'getBatch': 42,
#    'queryPlanning': 13,
#    'triggerExecution': 2445},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[hdfs://node-master:9000/user/root/onibus/source2/*/*]',
#     'startOffset': None,
#     'endOffset': {'logOffset': 0},
#     'numInputRows': 5846,
#     'processedRowsPerSecond': 2391.002044989775}],
#   'sink': {'description': 'ForeachBatchSink'}},
#  {'id': 'aaa8d33d-2584-4d1f-a3b7-e3c707e0552c',
#   'runId': '33371245-cde2-4d37-9e90-9f308cd8792e',
#   'name': None,
#   'timestamp': '2023-08-25T00:54:00.001Z',
#   'batchId': 1,
#   'numInputRows': 16660,
#   'inputRowsPerSecond': 576.2911204123284,
# ...

# %%
# stream_handle.stop()

# %% [markdown]
# > interrupt cell without stopping kernel: `ESC + I (2x)`<br/>
# > by Pedro Nora & ChatGPT

# %%
p = Process(target=loop)
p.start()
# Out:
# 1 - fetching API
# 2 - fetching API
# 3 - fetching API
# 4 - fetching API
# 5 - fetching API
# 6 - fetching API

# %%
! hadoop fs -ls /user/root/onibus/source2/
# Out:
# Found 4 items
# drwxr-xr-x   - root supergroup          0 2023-08-25 00:50 /user/root/onibus/source2/20230824_214956
# drwxr-xr-x   - root supergroup          0 2023-08-25 00:51 /user/root/onibus/source2/20230824_215108
# drwxr-xr-x   - root supergroup          0 2023-08-25 00:52 /user/root/onibus/source2/20230824_215211
# drwxr-xr-x   - root supergroup          0 2023-08-25 00:53 /user/root/onibus/source2/20230824_215316

# %%
! hadoop fs -ls /user/root/onibus/sink2/
# Out:
# Found 2 items
# drwxr-xr-x   - root supergroup          0 2023-08-25 00:53 /user/root/onibus/sink2/20230824_215331
# drwxr-xr-x   - root supergroup          0 2023-08-25 00:54 /user/root/onibus/sink2/20230824_215401

# %%
dir_source, dir_sink = "/user/root/onibus/source2/*/*", "/user/root/onibus/sink2/*/*"

# %%
schema_sink = StructType([
    StructField("ordem", StringType(), True),
    StructField("linha", StringType(), True),
    StructField("velocidade", IntegerType(), True),
])

# %%
df_sink = spark.read.schema(schema_sink).csv(dir_sink)

# %%
shape(df_sink)
# Out:
# (4550, 3)

# %%
df_sink.show()
# Out:
# +-----+-----+----------+
# |ordem|linha|velocidade|
# +-----+-----+----------+
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# | null| null|      null|
# +-----+-----+----------+
# only showing top 20 rows

# %%
df_source = spark.read.schema(schema).json(dir_source)

# %%
shape(df_source)
# Out:
# (71685, 8)
